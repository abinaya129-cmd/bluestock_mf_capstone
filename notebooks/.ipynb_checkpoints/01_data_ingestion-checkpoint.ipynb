# %% [markdown]
# # Data Ingestion
#
# Loaded all 10 mutual fund datasets.
#
# Performed:
# - Shape verification
# - Data type inspection
# - Head inspection
# - AMFI validation
# - Live NAV fetching
